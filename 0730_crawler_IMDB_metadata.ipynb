# %%
# -*- coding: utf-8 -*-
import requests
import sys
import time
import pandas as pd
import json
from bs4 import BeautifulSoup
import multiprocessing

HTML_PARSER   = "html.parser"
USER_AGENT    = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/59.0.3071.115 Safari/537.36'
HEADERS       = {'User-Agent': USER_AGENT}
MOVIE_ID_URL  = 'https://www.imdb.com/title/'
KEY = '<e7a9762dabfdc186e180a0791bb06e7c>'
head = ["id", "rating", "dircetor",
			"stars", "style", "runtime", "reviews_user", "reviews_critic", "budget"]
fileName = '6cate/6_cate_v1_all_input_prepared_3436_movies.csv'



def Mlist(file):
    print(file)
    df = pd.read_csv(file)
    #j = 0
    for i in range(0, len(df.imdb_id)):
        print(i)
        Movie(df.imdb_id[i])

def Movie(title):
	data_list = []
	style = []
	offic_metadata_PATTERN = 'https://api.themoviedb.org/3/movie/'+ title +'?api_key=e7a9762dabfdc186e180a0791bb06e7c'
	offic_results = requests.get(offic_metadata_PATTERN.format(key=KEY))
	imdb_api_response = offic_results.json()
	runtime = imdb_api_response['runtime']
	budget  = imdb_api_response['budget']
	movie_req = requests.get(MOVIE_ID_URL+title, headers = HEADERS)
	if movie_req.status_code == requests.codes.ok:
		print('URL OK')
		stars = ''
		soup = BeautifulSoup(movie_req.content, HTML_PARSER)
		if len(soup.select('span[itemprop="ratingValue"]')) == 0:
			rank = 'no data'
		else:
			rank = soup.select('span[itemprop="ratingValue"]')[0].text
		if len(soup.select('span[itemprop="name"]')) == 0:
			dircetor = 'no data'
		else:
			dircetor = soup.select('span[itemprop="name"]')[0].text
		if len(soup.select('span[itemprop="name"]')) == 0:
			stars = 'no data'
		else:
			for str in range(0,len(soup.select('span[itemprop="actors"]'))):
				stars+=soup.select('span[itemprop="actors"]')[str].text.strip()
		if len(soup.select('span[itemprop="genre"]')) == 0:
			style = 'no data'
		else:
			for sty in range(0,len(soup.select('span[itemprop="genre"]'))):
				style.append(soup.select('span[itemprop="genre"]')[sty].text.strip())    
		if len(soup.select('div.titleReviewbarItemBorder > div > span > a')) == 0:
			reviews_user = 'no data'
			reviews_critic = 'no data'
		elif len(soup.select('div.titleReviewbarItemBorder > div > span > a')) == 1:
			if 'user' in soup.select('div.titleReviewbarItemBorder > div > span > a')[0].text.strip():
				reviews_user = soup.select('div.titleReviewbarItemBorder > div > span > a')[0].text.strip().replace(' user','')
				reviews_critic = 'no data'
			if 'critic' in soup.select('div.titleReviewbarItemBorder > div > span > a')[0].text.strip():
				reviews_user = 'no data'
				reviews_critic = soup.select('div.titleReviewbarItemBorder > div > span > a')[0].text.strip().replace(' critic','')
		elif len(soup.select('div.titleReviewbarItemBorder > div > span > a')) == 2:
			if 'user' in soup.select('div.titleReviewbarItemBorder > div > span > a')[0].text.strip():
				reviews_user = soup.select('div.titleReviewbarItemBorder > div > span > a')[0].text.strip().replace(' user','')
			if 'critic' in soup.select('div.titleReviewbarItemBorder > div > span > a')[1].text.strip():
				reviews_critic = soup.select('div.titleReviewbarItemBorder > div > span > a')[1].text.strip().replace(' critic','')
	data_list.append([title, rank, dircetor, stars, style, runtime, reviews_user, reviews_critic, budget])
	df = pd.DataFrame(data_list , columns = head)
	df.to_csv("0730_get_genre.csv", mode='a', header=False)

'''
def list2csv(result):
	for items in result:
		for data_list in items.get():
			print(data_list)
			

def movielist():
	pool = multiprocessing.Pool(processes=7)
	print('cpu_count:',multiprocessing.cpu_count())
	result = []
	
	for x in range(0,len(df.imdb_id)):
		if x%7 == 0:
			result.append(pool.apply_async(Movie,(df.imdb_id[0+x],)))
			result.append(pool.apply_async(Movie,(df.imdb_id[1+x],)))
			result.append(pool.apply_async(Movie,(df.imdb_id[2+x],)))
			result.append(pool.apply_async(Movie,(df.imdb_id[3+x],)))
			result.append(pool.apply_async(Movie,(df.imdb_id[4+x],)))
			result.append(pool.apply_async(Movie,(df.imdb_id[5+x],)))
			result.append(pool.apply_async(Movie,(df.imdb_id[6+x],)))
	list2csv(result)
	pool.close()
	pool.join()
'''
if __name__ == '__main__':
	start = time.time()
	Mlist(fileName)
	print('All cost',time.time()-start)
# Out:
# 6cate/6_cate_v1_all_input_prepared_3436_movies.csv
# 0
# URL OK
# 1
# URL OK
# 2
# URL OK
# 3
# URL OK
# 4
# URL OK
# 5
# URL OK
# 6
# URL OK
# 7
# URL OK
# 8
# URL OK
# 9
# URL OK
# 10
# URL OK
# 11
# URL OK
# 12
# URL OK
# 13
# URL OK
# 14
# URL OK
# 15
# URL OK
# 16
# URL OK
# 17
# URL OK
# 18
# URL OK
# 19
# URL OK
# 20
# URL OK
# 21
# URL OK
# 22
# URL OK
# 23
# URL OK
# 24
# URL OK
# 25
# URL OK
# 26
# URL OK
# 27
# URL OK
# 28
# URL OK
# 29
# URL OK
# 30
# URL OK
# 31
# URL OK
# 32
# URL OK
# 33
# URL OK
# 34
# URL OK
# 35
# URL OK
# 36
# URL OK
# 37
# URL OK
# 38
# URL OK
# 39
# URL OK
# 40
# URL OK
# 41
# URL OK
# 42
# URL OK
# 43
# URL OK
# 44
# URL OK
# 45
# URL OK
# 46
# URL OK
# 47
# URL OK
# 48
# URL OK
# 49
# URL OK
# 50
# URL OK
# 51
# URL OK
# 52
# URL OK
# 53
# URL OK
# 54
# URL OK
# 55
# URL OK
# 56
# URL OK
# 57
# URL OK
# 58
# URL OK
# 59
# URL OK
# 60
# URL OK
# 61
# URL OK
# 62
# URL OK
# 63
# URL OK
# 64
# URL OK
# 65
# URL OK
# 66
# URL OK
# 67
# URL OK
# 68
# URL OK
# 69
# URL OK
# 70
# URL OK
# 71
# URL OK
# 72
# URL OK
# 73
# URL OK
# 74
# URL OK
# 75
# URL OK
# 76
# URL OK
# 77
# URL OK
# 78
# URL OK
# 79
# URL OK
# 80
# URL OK
# 81
# URL OK
# 82
# URL OK
# 83
# URL OK
# 84
# URL OK
# 85
# URL OK
# 86
# URL OK
# 87
# URL OK
# 88
# URL OK
# 89
# URL OK
# 90
# URL OK
# 91
# URL OK
# 92
# URL OK
# 93
# URL OK
# 94
# URL OK
# 95
# URL OK
# 96
# URL OK
# 97
# URL OK
# 98
# URL OK
# 99
# URL OK
# 100
# URL OK
# 101
# URL OK
# 102
# URL OK
# 103
# URL OK
# 104
# URL OK
# 105
# URL OK
# 106
# URL OK
# 107
# URL OK
# 108
# URL OK
# 109
# URL OK
# 110
# URL OK
# 111
# URL OK
# 112
# URL OK
# 113
# URL OK
# 114
# URL OK
# 115
# URL OK
# 116
# URL OK
# 117
# URL OK
# 118
# URL OK
# 119
# URL OK
# 120
# URL OK
# 121
# URL OK
# 122
# URL OK
# 123
# URL OK
# 124
# URL OK
# 125
# URL OK
# 126
# URL OK
# 127
# URL OK
# 128
# URL OK
# 129
# URL OK
# 130
# URL OK
# 131
# URL OK
# 132
# URL OK
# 133
# URL OK
# 134
# URL OK
# 135
# URL OK
# 136
# URL OK
# 137
# URL OK
# 138
# URL OK
# 139
# URL OK
# 140
# URL OK
# 141
# URL OK
# 142
# URL OK
# 143
# URL OK
# 144
# URL OK
# 145
# URL OK
# 146
# URL OK
# 147
# URL OK
# 148
# URL OK
# 149
# URL OK
# 150
# URL OK
# 151
# URL OK
# 152
# URL OK
# 153
# URL OK
# 154
# URL OK
# 155
# URL OK
# 156
# URL OK
# 157
# URL OK
# 158
# URL OK
# 159
# URL OK
# 160
# URL OK
# 161
# URL OK
# 162
# URL OK
# 163
# URL OK
# 164
# URL OK
# 165
# URL OK
# 166
# URL OK
# 167
# URL OK
# 168
# URL OK
# 169
# URL OK
# 170
# URL OK
# 171
# URL OK
# 172
# URL OK
# 173
# URL OK
# 174
# URL OK
# 175
# URL OK
# 176
# URL OK
# 177
# URL OK
# 178
# URL OK
# 179
# URL OK
# 180
# URL OK
# 181
# URL OK
# 182
# URL OK
# 183
# URL OK
# 184
# URL OK
# 185
# URL OK
# 186
# URL OK
# 187
# URL OK
# 188
# URL OK
# 189
# URL OK
# 190
# URL OK
# 191
# URL OK
# 192
# URL OK
# 193
# URL OK
# 194
# URL OK
# 195
# URL OK
# 196
# URL OK
# 197
# URL OK
# 198
# URL OK
# 199
# URL OK
# 200
# URL OK
# 201
# URL OK
# 202
# URL OK
# 203
# URL OK
# 204
# URL OK
# 205
# URL OK
# 206
# URL OK
# 207
# URL OK
# 208
# URL OK
# 209
# URL OK
# 210
# URL OK
# 211
# URL OK
# 212
# URL OK
# 213
# URL OK
# 214
# URL OK
# 215
# URL OK
# 216
# URL OK
# 217
# URL OK
# 218
# URL OK
# 219
# URL OK
# 220
# URL OK
# 221
# URL OK
# 222
# URL OK
# 223
# URL OK
# 224
# URL OK
# 225
# URL OK
# 226
# URL OK
# 227
# URL OK
# 228
# URL OK
# 229
# URL OK
# 230
# URL OK
# 231
# URL OK
# 232
# URL OK
# 233
# URL OK
# 234
# URL OK
# 235
# URL OK
# 236
# URL OK
# 237
# URL OK
# 238
# URL OK
# 239
# URL OK
# 240
# URL OK
# 241
# URL OK
# 242

# %%
df = pd.read_csv('0730_dadada.csv')
df.head()
# Out:
#    index         id  star                   dic  \
# 0      0  tt0118523   4.8          Scott Winant
# 1      0  tt0119324   6.7           Mark Waters
# 2      0  tt0119746   6.1       Bart Freundlich
# 3      0  tt0119578   6.8          Joe Mantello
# 4      0  tt0119256   7.3  Paul Thomas Anderson
#
#                                                actor  \
# 0    Jeanne Tripplehorn,Dylan McDermott,John Plumpis
# 1           Parker Posey,Josh Hamilton,Tori Spelling
# 2              Julianne Moore,Roy Scheider,Noah Wyle
# 3  Jason Alexander,Stephen Spinella,Stephen Bogardus
# 4   Philip Baker Hall,John C. Reilly,Gwyneth Paltrow
#
#                             genre  runtime  user  critic   budget
# 0           ['Romance', 'Comedy']      113    39      22  1000000
# 1             ['Comedy', 'Drama']       85    89      41  1500000
# 2  ['Comedy', 'Drama', 'Romance']       93    36      34  2000000
# 3  ['Comedy', 'Drama', 'Romance']      108    52      13  2000000
# 4              ['Crime', 'Drama']       96   149      65  3000000

# %%
type(df.genre.iloc[1])
# Out:
# str
